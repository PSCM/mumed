# %% [markdown]
# # Versão simples

# %% [markdown]
# ## Bibliotecas

# %%
#Adaptado de https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/
# Importar as bibliotecas
import pandas as pd
import numpy as np
import re
import nltk
import os
from nltk.tokenize import word_tokenize
from collections import defaultdict
from nltk.corpus import wordnet as wn
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ## Módulos

# %%
# Download dos elementos necessários para conduzir as análises
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %% [markdown]
# ## Pré-processamento

# %%
# Carregar os arquivos .txt com as letras
path = '/content/drive/MyDrive/lyrics/' # criar pasta, caso utilize o Colab
files = os.listdir(path)
files.sort(key=lambda f: int(re.sub('\D', '', f)))

text  = []
id = []

for line in files:
  with open(path+line, 'r') as f:
    txt = f.read()
    text.append(txt)
    id.append(line)

# %%
# Criar a base de dados (df)
df = pd.DataFrame(zip(id, text), columns = ['id','lyrics'])
df.head(3)
# Out:
#       id                                             lyrics
# 0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...

# %%
# Limpar as letras
replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}

df['cleanLyrics'] = df['lyrics'].replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
df.head(3)
# Out:
#       id                                             lyrics  \
# 0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
#
#                                          cleanLyrics
# 0  well it s okay all across the usa it s another...
# 1  out of my mind on saturday night rollin in sig...
# 2  i m on it ooh i m on it i m so on it and howev...

# %% [markdown]
# ## Características

# %%
# Número de caracteres
df['charCount'] = df['cleanLyrics'].str.len()
# Número de palavras por letras
df['wordCount'] = df['cleanLyrics'].str.split().str.len()
df.head(3)
# Out:
#       id                                             lyrics  \
# 0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
#
#                                          cleanLyrics  charCount  wordCount
# 0  well it s okay all across the usa it s another...         97         22
# 1  out of my mind on saturday night rollin in sig...        124         25
# 2  i m on it ooh i m on it i m so on it and howev...        419         94

# %%
# Média de palavras por letras
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

# %%
df['avgWord'] = df['cleanLyrics'].apply(lambda x: avg_word(x))
df.head(3)
# Out:
#       id                                             lyrics  \
# 0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
#
#                                          cleanLyrics  charCount  wordCount  \
# 0  well it s okay all across the usa it s another...         97         22
# 1  out of my mind on saturday night rollin in sig...        124         25
# 2  i m on it ooh i m on it i m so on it and howev...        419         94
#
#     avgWord
# 0  3.454545
# 1  4.000000
# 2  3.468085

# %%
df.reset_index(inplace = True)
df['uniqueWords'] = pd.Series(np.arange(len(df)))

# %%
current = 0
for row in df.itertuples():
    df['uniqueWords'][current] = len(np.unique(df['cleanLyrics'].str.split()[current]))
    current = current + 1
df.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    index     id                                             lyrics  \
# 0      0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1      1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2      2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
#
#                                          cleanLyrics  charCount  wordCount  \
# 0  well it s okay all across the usa it s another...         97         22
# 1  out of my mind on saturday night rollin in sig...        124         25
# 2  i m on it ooh i m on it i m so on it and howev...        419         94
#
#     avgWord  uniqueWords
# 0  3.454545           18
# 1  4.000000           23
# 2  3.468085           55

# %%
df['uniqueWordsProp']  =  df['uniqueWords'] / df['wordCount']
df.head(3)
# Out:
#    index     id                                             lyrics  \
# 0      0  1.txt  Well, it's 1969, okay?\nAll across the USA\nIt...
# 1      1  2.txt  Out of my mind on Saturday night\n1970 rollin'...
# 2      2  3.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
#
#                                          cleanLyrics  charCount  wordCount  \
# 0  well it s okay all across the usa it s another...         97         22
# 1  out of my mind on saturday night rollin in sig...        124         25
# 2  i m on it ooh i m on it i m so on it and howev...        419         94
#
#     avgWord  uniqueWords  uniqueWordsProp
# 0  3.454545           18         0.818182
# 1  4.000000           23         0.920000
# 2  3.468085           55         0.585106

# %%
# Análise de sentimentos
sid = SentimentIntensityAnalyzer()

sentiments = df.apply(lambda r: sid.polarity_scores(r['lyrics']), axis=1)

# %%
d = pd.DataFrame(list(sentiments))
df = df.join(d)
df.dropna(inplace=True)

# %%
df.to_excel('lyrics.xlsx', index= False)

# %% [markdown]
# # Versão Completa

# %% [markdown]
# ## Bibliotecas

# %%
#Adaptado de https://www.analyticsvidhya.com/blog/2018/02/the-different-methods-deal-text-data-predictive-python/
# Importar as bibliotecas
import pandas as pd
import numpy as np
import re
import nltk
import os
from nltk.corpus import stopwords
from nltk.stem import 	WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import defaultdict
from nltk.corpus import wordnet as wn
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Módulos

# %%
# Download dos elementos necessários para conduzir as análises
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
stop = stopwords.words('english')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
# Acrescentar novas stop words
_new_stopwords_to_add = ['whoo', 'ah', 'usa', 'ohhh','ah','yeah','ye','ahahah', 'okay', 'oh','ahahah', 'hahahah', 'aaaaaaaaaaaah', 'ooh']
stop += _new_stopwords_to_add

# %%
# POS TAG
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

wl = WordNetLemmatizer()

# %% [markdown]
# ## Funções

# %%
# Função para lemmatizar junto com pos_tag
def convert(text):
    lemmatized_text = []
    for i, tag in pos_tag(text.split()):
        lemmatized_text.append(str(wl.lemmatize(i,tag_map[tag[0]])))

    return ' '.join(lemmatized_text)

# %% [markdown]
# ## Pré-processamento

# %%
# Carregar os arquivos .txt com as letras
path = '/content/lyrics/' # criar pasta, caso utilize o Colab
files = os.listdir(path)
files.sort(key=lambda f: int(re.sub('\D', '', f)))

text  = []
id = []

for line in files:
  with open(path+line, 'r') as f:
    txt = f.read()
    text.append(txt)
    id.append(line)

# %%
# Criar a base de dados (df)
df = pd.DataFrame(zip(id, text), columns = ['id','lyrics'])
df.head(3)
# Out:
#        id                                             lyrics
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...

# %%
# Limpar as letras
replacer = {'\n':' ',"[\[].*?[\]]": "",'[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’""′‘\\\]':" ", ' +': ' '}

df['cleanLyrics'] = df['lyrics'].replace(replacer, regex=True).apply(lambda x: x.strip()).apply(lambda x: " ".join(x.lower() for x in x.split()))
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...

# %%
# Remover stop words
df['cleanLyricsStop'] = df['cleanLyrics'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics  \
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...
#
#                                      cleanLyricsStop
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty years married wait fifty first roll arou...

# %%
# Corrigir escrita (ex: rollin -> rolling)
df['cleanLyricsStop'] = df['cleanLyricsStop'].apply(lambda x: str(TextBlob(x).correct()))
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics  \
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...
#
#                                      cleanLyricsStop
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty years married wait fifty first roll arou...

# %%
#Lemmatizar
df['lyricsLemma'] = df['cleanLyricsStop'].apply(lambda x: convert(x))
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics  \
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...
#
#                                      cleanLyricsStop  \
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty years married wait fifty first roll arou...
#
#                                          lyricsLemma
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty year marry wait fifty first roll around ...

# %%
'''
#Stemming
st = PorterStemmer()
df['lyricsStemm'] = df['cleanLyricsStop'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
df.head(3)

'''

# %% [markdown]
# ## Características

# %%
# Número de palavras por letras
df['wordCount'] = df['cleanLyrics'].str.split().str.len()
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics  \
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...
#
#                                      cleanLyricsStop  \
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty years married wait fifty first roll arou...
#
#                                          lyricsLemma  wordCount
# 0  however want get tonight ho night ho get beat ...         94
# 1  hey one big queen one stop red light red green...         48
# 2  fifty year marry wait fifty first roll around ...         47

# %%
# Número de stop words por letras
df['stopwords']  =  df['cleanLyrics'].apply(lambda x: len([x for x in x.split() if x in stop]))
df.head(3)
# Out:
#        id                                             lyrics  \
# 0   4.txt  I'm on it, ooh, I'm on it\nI'm so on it, and h...
# 1   9.txt  Hey I'm one big queen\nNo one can stop me\nRed...
# 2  10.txt  For fifty years they've been married\nAnd they...
#
#                                          cleanLyrics  \
# 0  i m on it ooh i m on it i m so on it and howev...
# 1  hey i m one big queen no one can stop me red l...
# 2  for fifty years they ve been married and they ...
#
#                                      cleanLyricsStop  \
# 0  however want get tonight ho night ho get beat ...
# 1  hey one big queen one stop red light red green...
# 2  fifty years married wait fifty first roll arou...
#
#                                          lyricsLemma  wordCount  stopwords
# 0  however want get tonight ho night ho get beat ...         94         54
# 1  hey one big queen one stop red light red green...         48         19
# 2  fifty year marry wait fifty first roll around ...         47         28

# %%
# Número de palavras por letras (lemma)
df['wordCountLemma']  =  df['lyricsLemma'].str.split().str.len()
df.head(3)

# %%
#df.reset_index(inplace = True)
df['uniqueLyrics'] = pd.Series(np.arange(len(df)))

# %%
df['uniqueLyrics']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 914    914
# 915    915
# 916    916
# 917    917
# 918    918
# Name: uniqueLyrics, Length: 919, dtype: int64

# %%
# Riqueza do vocabulário
current = 0
for row in df.itertuples():
    df['uniqueLyrics'][current] = len(np.unique(df['lyricsLemma'].str.split()[current]))
    current = current + 1
df.head(3)

# %% [markdown]
# ## BOW e TF-IDF

# %%
# Bag of words (BOW)
bow = CountVectorizer(max_features=50, ngram_range=(2,2),analyzer = "word")
train_bow = bow.fit_transform(df['lyricsLemma'])
lemmaBOW2gram = pd.DataFrame(bow.transform(df['lyricsLemma']).toarray(), columns=sorted(bow.vocabulary_.keys()))
lemmaBOW2gram

# %%
#TFIDF
tfidf = TfidfVectorizer(max_features=50, ngram_range=(2,2),analyzer = "word")
train_vect = tfidf.fit_transform(df['lyricsLemma'])

lemmaTFIDF2gram = pd.DataFrame(tfidf.transform(df['lyricsLemma']).toarray(), columns=sorted(tfidf.vocabulary_.keys()))
lemmaTFIDF2gram
